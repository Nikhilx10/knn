# %% [markdown]
# Implementation Steps with scikit-learn

# %% [markdown]
# 1. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# 2. Generate Synthetic Data

# %%
X, y = make_blobs(n_samples=500, n_features=2, centers=4,
                  cluster_std=1.5, random_state=4)
plt.figure(figsize=(10,6))
plt.scatter(X[:,0], X[:,1], c=y, marker='*', s=100, edgecolors='black')
plt.title("Synthetic Dataset with 4 Classes")
plt.show()

# %% [markdown]
# 3. Split Data into Train/Test Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# 4. Train KNN Models

# %%
knn5 = KNeighborsClassifier(n_neighbors=5)
knn1 = KNeighborsClassifier(n_neighbors=1)

knn5.fit(X_train, y_train)
knn1.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# 5. Evaluate Performance

# %%
y_pred_5 = knn5.predict(X_test)
y_pred_1 = knn1.predict(X_test)

print(f"Accuracy with k=5: {accuracy_score(y_test, y_pred_5)*100:.2f}%")  # e.g., 92.0%
print(f"Accuracy with k=1: {accuracy_score(y_test, y_pred_1)*100:.2f}%")  # e.g., 88.8%
# Out:
# Accuracy with k=5: 93.60%
# Accuracy with k=1: 90.40%
